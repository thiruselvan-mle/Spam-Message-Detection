# %% [markdown]
# # Model Training (SMS Spam Collection Dataset)
#
# in this notebook,we will
# - Load Dataset
# - Split Data
# - Vectorize Text
# - Compare Algorithm
# - Train with Final Model
# - Save Model and Vectorizer

# %% [markdown]
# ## Step 1: Set project root for python imports

# %%
import os 
import sys

sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ## Step 2: Load Dataset

# %%
from src.data import load_data
df = load_data(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed\Cleaned-spam.csv")
# Out:
# 'Dataset successfully loaded'
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Step 3: Split Data

# %%
from src.model import (split_data,
vectorizer_text,
compare_algorithm,
compare_acuu,
train_model,
save_model_vector
)
x_train, x_test, y_train, y_test = split_data(df)

# %% [markdown]
# ## Step 4: Text Vectorization (TF-IDF)

# %%
x_train, x_test, vectorizer = vectorizer_text(x_train, x_test)
# Out:
# Shape of TF-IDF Vectors:
# Train (4135, 3000)
# Test (4135, 3000)

# %% [markdown]
# ## Step 5: Comparing Algorithm

# %%
results_df, results, names, res = compare_algorithm(x_train, y_train)
# Out:
#   Model   Accuracy
# 1   MNB  97.872174
# 2    RF  97.726720
# 4   SVC  97.461195
# 3    DT  95.937526
# 0    LR  95.477945
# 5   KNN  91.125031

# %% [markdown]
# ## Step 6: Compare Accuracy Using Barplot

# %%
compare_acuu(names,res)

# %% [markdown]
# ### insight
#  - Multinomial Naive Bayes achieved the highest accuracy (~98%), followed closely by Random Forest and SVC. Logistic Regression and Decision Tree performed moderately, while KNN had the lowest performance, making it less suitable for this dataset.

# %% [markdown]
# ## Step 7: Train with Final Model

# %% [markdown]
# We select **MultinomaialNB** as our best model.

# %%
model = train_model(x_train,y_train)

# %% [markdown]
# ## Step 8: Save Model and Vectorizer

# %%
save_model_vector(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\models",model,vectorizer)
# Out:
# Model and Vectorizer Saved Successfully

# %% [markdown]
# ## Model Training Summary
#  - Vectorized Text
#  - Compared Algorithm
#  - Selected **MultinomialNB** as our best model
#  - Saved Model and Vectorizer

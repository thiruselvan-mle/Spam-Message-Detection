# %% [markdown]
# # Exporatory Data Analysis-EDA (SMS Spam Collection Dataset)
#
# in this notebook,we will:
#  - Load Dataset
#  - Plot Distribution of Labels
#  - Compare Average Message Length between Ham and Spam
#  - Plot Word Count of Labels
#  - Feature Correlation Heatmap
#  - Save EDA Results Summary

# %% [markdown]
# ## Step 1: Set project root for python imports

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ## Step 2: Load Cleaned Dataset

# %%
from src.data import load_data

df = load_data(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed\Cleaned-spam.csv")
# Out:
# 'Dataset successfully loaded'
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Step 3: Distribution of Labels

# %%
from src.utils import(distribute_labels,
add_msg_length,
compare_avg_length,
msg_length_distribute,
word_count,
corr_heatmap,
save_eda_summary
)

distribute_labels(df)

# %% [markdown]
# ### insight
# - The dataset has more ham (0) messages than spam (1).
# - The data is slightly imbalanced

# %% [markdown]
# ## Step 4: Add Message_length Feature

# %%
df = add_msg_length(df)

# %% [markdown]
# ## Step 5: Compare Average message length between Ham and Spam

# %%
avg_length = compare_avg_length(df)
# Out:
# Average essage length of Ham(0) and Spam(1)
#
# label
# 0     70.459256
# 1    137.891271
# Name: message_length, dtype: float64

# %% [markdown]
# ### insight
# - On average, spam messages are longer than ham messages.

# %% [markdown]
# ## Step 6: Message Length Distribution

# %%
msg_length_distribute(df)

# %% [markdown]
# ### insight
#  - Ham messages are generally short and direct (often between 20–100 characters).
#  - Spam messages have a wider range, often much longer.
#  - This difference can help the model distinguish between ham and spam based on text length.

# %% [markdown]
# ## Step 7: Word Count Feature

# %%
df = word_count(df)

# %% [markdown]
# ### insight
#  - Spam messages usually have more words than ham messages.
#  - The boxplot shows that spam has a higher median and more variability — indicating spam texts tend to be wordier.

# %% [markdown]
# ## Step 8: Correlation Heatmap

# %%
corr_heatmap(df)

# %% [markdown]
# ### insight
#  - There’s a strong positive correlation between message_length and word_count.

# %% [markdown]
# ## Step 8: Save EDA Result Summary

# %%
save_eda_summary(df, avg_length, r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed", "eda-summary.csv")
# Out:
# EDA summary successfully saved into D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed\eda-summary.csv

# %% [markdown]
# ## EDA Summary
# - Ploted the distribution of labels
# - ploted message length frequency
# - ploted word count of labels
# - ploted correlation heatmap
# - saved EDA results summary

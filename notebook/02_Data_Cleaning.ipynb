# %% [markdown]
# # Data Cleaning (SMS Spam Collection Dataset)
#
# in this notebook,we will:
#  - Load Dataset
#  - Remove Unwanted columns
#  - Rename columns
#  - Remove Duplicate rows
#  - Encode Labels
#  - Save Cleaned data

# %% [markdown]
# ## Step 1: Set project root for python imports

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ## Step 2: Load Dataset

# %%
from src.data import ( load_data,
check_mis_val,
remove_cols,
rename_cols,
remove_duplicate_rows,
encode_labels,
data_info,
save_clean_data
)
                    
df = load_data(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\raw/spam.csv", 'latin-1')
# Out:
# 'Dataset successfully loaded'
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ## Step 3: Missing Values

# %%
check_mis_val(df)
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %% [markdown]
# ## Step 4: Remove Redundant Columns

# %%
df = remove_cols(df)

# %% [markdown]
# ## Step 5: Rename Colunms

# %%
df = rename_cols(df)

# %% [markdown]
# ## Step 6: Remove Duplicate rows

# %%
df = remove_duplicate_rows(df)
# Out:
# Duplicate rows:403
#
# After_drop Duplicate rows:0

# %% [markdown]
# ## Step 7: Encode labels

# %%
df = encode_labels(df)

# %% [markdown]
# ## Step 8: Cleaned Data Info

# %%
data_info(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5169 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5169 non-null   int64
#  1   message  5169 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 121.1+ KB
# None

# %% [markdown]
# ## Step 9: Save Cleaned Data

# %%
save_clean_data(df ,r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed" ,"Cleaned-spam.csv")
# Out:
# Cleaned Dataset save into D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed\Cleaned-spam.csv

# %% [markdown]
# ## Data Cleaning Summary
#  - Dropped Irrelevant columns
#  - Renamed Columns
#  - Removed duplicates rows
#  - Encoded labels
#  - **saved dataset into** D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed

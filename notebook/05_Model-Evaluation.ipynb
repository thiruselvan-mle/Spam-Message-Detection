# %% [markdown]
# # Model Evaluation (SMS Spam Collection Dataset)
#
# in this notebook,we will:
#  - Load the Saved Model and Vectorizer
#  - Load Cleaned Dataset
#  - Split Data for Testing
#  - Evaluate Metrics
#  - Classification report
#  - Confusion Matrix
#  - Test with a Custom Message

# %% [markdown]
# ## Step 1: Set project root for python imports

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ## Step 2: Load Model and Vectorizer

# %%
from src.model import (load_model_vector,
split_data,
transform_test,
make_predict,
evaluate_metrics,
cls_report,
plot_cm,
test_custom_msg
)

model = load_model_vector(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\models\spam_model.pkl")
vectorizer = load_model_vector(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\models\spam_vectorizer.pkl")
# Out:
# Loaded successfully from D:\Thiru\ML_Projects\GitHub\spam-detection-model\models\spam_model.pkl
# Loaded successfully from D:\Thiru\ML_Projects\GitHub\spam-detection-model\models\spam_vectorizer.pkl

# %% [markdown]
# ## Step 3: Load Cleaned dataset"

# %%
from src.data import load_data
df = load_data(r"D:\Thiru\ML_Projects\GitHub\spam-detection-model\data\processed\Cleaned-spam.csv")
# Out:
# 'Dataset successfully loaded'
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Step 4: Split data for testing

# %%
x_train, x_test, y_train, y_test = split_data(df)

# %% [markdown]
# ## Step 5: Transform Test Data

# %%
x_test = transform_test(x_test, vectorizer)

# %% [markdown]
# ## Step 6: Make Prediction

# %%
y_pred = make_predict(x_test, model)

# %% [markdown]
# ## Step 7: Evaluate Metrics

# %%
acc ,prec ,rec, f1 =evaluate_metrics(y_test, y_pred)
# Out:
# Model Evaluation Results:
# Accuracy: 97.29
# Precision: 99.05
# Recall: 79.39
# f1_score: 88.14

# %% [markdown]
# ## Step 8: Classification_report

# %%
cls_report(y_pred,y_test)
# Out:
#               precision    recall  f1-score   support
#
#          Ham       1.00      0.97      0.98       929
#         Spam       0.79      0.99      0.88       105
#
#     accuracy                           0.97      1034
#    macro avg       0.90      0.98      0.93      1034
# weighted avg       0.98      0.97      0.97      1034

# %% [markdown]
# ## Step 9: Confusion_matrix

# %%
plot_cm(y_pred,y_test)

# %% [markdown]
# ## Step 10: Test with a Custom Message

# %%
test_custom_msg(vectorizer, model, "Congratulations! You've won a free ticket to Goa. Click here to claim.")
# Out:
# Message 'Congratulations! You've won a free ticket to Goa. Click here to claim.' - predicted as Spam

# %% [markdown]
# ## Model Evaluation Summary
# - Evaluate Metrics show accuracy:`97.29`, precision:`99.05`, reacll:`79.39`, F1_score:`88.14`
# - Confusion matrix show True positive, True Negative, False Positive, False Negative
# - Tested with a Custom Message Model predicted as **Spam**
